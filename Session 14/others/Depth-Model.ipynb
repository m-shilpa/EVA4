# %% [markdown]
# <a href="https://colab.research.google.com/github/mshilpaa/EVA4/blob/master/Session%2014/others/Depth-Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
from PIL import Image

# %%
# !git clone https://github.com/mshilpaa/DenseDepth.git
# Out:
# Cloning into 'DenseDepth'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 48 (delta 5), reused 43 (delta 3), pack-reused 0
# Unpacking objects: 100% (48/48), done.

# %%
# !wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5 -O ./DenseDepth/nyu.h5
# Out:
# --2020-05-02 18:15:30--  https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.36.106
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.36.106|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 172897376 (165M) [application/h5]
# Saving to: ‘./DenseDepth/nyu.h5’
#
# ./DenseDepth/nyu.h5 100%[===================>] 164.89M  20.9MB/s    in 8.8s
#
# 2020-05-02 18:15:39 (18.8 MB/s) - ‘./DenseDepth/nyu.h5’ saved [172897376/172897376]

# %%
import os
os.mkdir('/content/DenseDepth/output')
os.mkdir('/content/DenseDepth/test_images')

# %%
# !cd DenseDepth; python test.py
# Out:
# Using TensorFlow backend.
# Loading model...
#
# Model loaded (nyu.h5).
#
# Loaded (11) images of size (480, 640, 3).
# <Figure size 1000x500 with 1 Axes>

# %%
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(20,20))
plt.imshow( io.imread('./DenseDepth/test.png') )

# %% [markdown]
# The model accepts input size (480,640) but if image size is lesser then it gives bad results.

# %%
# !cd DenseDepth; python test.py --input '/content/DenseDepth/*.jpg'
# Out:
# Using TensorFlow backend.
# Loading model...
#
# Model loaded (nyu.h5).
#
# Loaded (2) images of size (224, 224, 3).
# <Figure size 1000x500 with 1 Axes>

# %% [markdown]
#  The output image size is half the input image size.

# %%
Image.open('/content/DenseDepth/output/depth_img-1.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=112x112 at 0x7F0688F76EF0>

# %%
Image.open('/content/DenseDepth/output/depth_img-0.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=112x112 at 0x7F068773B048>

# %% [markdown]
# After resizing the same images to (480,640). Also resizing output image size to the --output_img_size args given

# %%
# !cd DenseDepth; python test.py --input '/content/DenseDepth/test_images/*.jpg' --output_img_size 224
# Out:
# Using TensorFlow backend.
# Loading model...
#
# Model loaded (nyu.h5).
#
# Loaded (2) images of size (640, 480, 3).
#
# Loaded (2) images of size (640, 480, 3).
# <Figure size 1000x500 with 1 Axes>

# %%
Image.open('/content/DenseDepth/output/depth_img-0.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F06876A1438>

# %%
Image.open('/content/DenseDepth/output/depth_img-1.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224 at 0x7F06876A1278>
